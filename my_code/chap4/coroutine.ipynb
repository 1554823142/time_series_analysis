# %% [markdown]
# #### taxi_id_number 生成器
# 生成 num_taxis 个唯一的出租车 ID，且每个 ID 是随机的

# %%
import numpy as np

def taxi_id_number(num_taxis):
    arr = np.arange(num_taxis)
    np.random.shuffle(arr)
    for i in range(num_taxis):
        yield arr[i]    # 每次调用 next() 时，生成器从上次暂停的位置继续执行，返回当前的出租车 ID，直到没有更多的 ID 为止

# %% [markdown]
# #### shift_info 生成器
# 生成每个出租车的班次信息，包括班次的开始时间、结束时间和预计的平均旅行次数

# %%
def shift_info():           # 分时间0, 8, 16; 并且不同时间段内，平均接客次数也是不同的
    start_times_and_freqs = [(0, 8), (8, 30), (16, 15)]
    indices = np.arange(len(start_times_and_freqs))
    while True:                         # 在白天安排了较多的出租车，而为傍晚或整宿的班次安排了较少的出租车
        idx = np.random.choice(indices, p=[0.25, 0.5, 0.25])
        start = start_times_and_freqs[idx]
        yield (start[0], start[0] + 7.5, start[1])  # 返回开始, 结束时间 以及 接客数

# %% [markdown]
# #### taxi_process 生成器
# 模拟出租车的工作流程，包括接乘客、送乘客等事件，直到班次结束
#
# 使用**泊松分布**来模拟事件之间的时间间隔（`np.random.poisson()`）

# %%
from dataclasses import dataclass

@dataclass
class TimePoint:
    taxi_id: int
    name: str
    time: float

    def __lt__(self, other):
        return self.time < other.time

# %%
def taxi_process(taxi_id_generator, shift_info_generator):
    taxi_id = next(taxi_id_generator)
    shift_start, shift_end, shift_mean_trips = next(shift_info_generator)
    # 正态分布模拟接客数
    actual_trips = round(np.random.normal(loc=shift_mean_trips, scale=2))
    average_trip_time = 6.5 / shift_mean_trips * 60  # 将平均行程时长的单位转换为分钟
    between_events_time = 1.0 / (shift_mean_trips - 1) * 60  # 出租车的利用率较高
    
    time = shift_start
    yield TimePoint(taxi_id, 'start shift', time)
    
    deltaT = np.random.poisson(between_events_time) / 60
    time += deltaT
    
    for i in range(actual_trips):
        yield TimePoint(taxi_id, 'pick up    ', time)
        deltaT = np.random.poisson(average_trip_time) / 60
        time += deltaT
        yield TimePoint(taxi_id, 'drop off   ', time)
        deltaT = np.random.poisson(between_events_time) / 60
        time += deltaT
    
    deltaT = np.random.poisson(between_events_time) / 60
    time += deltaT
    yield TimePoint(taxi_id, 'end shift  ', time)

# %% [markdown]
# #### Simulator 类
# 控制整个模拟流程，生成并排序所有出租车的事件，然后逐步输出事件

# %%
import queue

class Simulator:
    def __init__(self, num_taxis):
        self._time_points = queue.PriorityQueue()
        taxi_id_generator = taxi_id_number(num_taxis)
        shift_info_generator = shift_info()
        self._taxis = [
            taxi_process(taxi_id_generator, shift_info_generator) for i in range(num_taxis)
        ]
        self._prepare_run()

    def _prepare_run(self):
        for t in self._taxis:
            while True:
                try:
                    e = next(t)
                    self._time_points.put(e)
                except:
                    break

    def run(self):
        sim_time = 0
        while sim_time < 24:
            if self._time_points.empty():
                break
            p = self._time_points.get()
            sim_time = p.time
            print(p)

# %%
sim = Simulator(1000)
sim.run()
# Out:
# TimePoint(taxi_id=np.int64(961), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(464), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(161), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(831), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(993), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(965), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(433), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(553), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(763), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(926), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(421), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(550), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(591), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(760), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(827), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(166), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(450), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(959), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(555), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(250), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(197), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(266), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(505), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(542), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(451), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(775), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(228), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(425), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(976), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(543), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(866), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(681), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(837), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(784), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(398), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(931), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(143), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(460), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(989), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(139), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(382), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(589), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(795), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(30), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(526), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(561), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(124), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(396), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(654), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(248), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(740), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(243), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(665), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(371), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(777), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(37), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(565), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(540), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(908), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(340), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(529), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(802), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(999), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(612), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(330), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(68), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(459), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(194), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(511), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(822), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(804), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(915), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(778), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(653), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(320), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(351), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(150), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(357), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(391), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(619), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(730), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(214), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(664), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(373), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(114), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(862), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(790), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(722), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(753), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(89), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(986), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(769), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(262), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(453), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(710), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(939), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(5), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(679), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(100), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(734), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(570), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(571), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(633), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(466), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(899), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(889), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(284), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(982), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(328), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(360), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(472), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(537), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(609), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(361), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(975), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(834), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(298), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(892), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(947), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(287), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(325), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(186), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(132), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(744), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(916), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(697), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(721), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(603), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(528), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(761), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(605), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(346), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(350), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(901), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(548), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(942), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(701), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(64), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(786), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(871), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(123), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(380), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(618), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(921), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(251), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(559), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(256), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(532), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(192), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(971), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(309), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(678), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(904), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(177), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(798), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(411), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(685), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(483), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(184), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(164), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(656), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(22), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(909), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(955), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(294), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(355), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(934), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(705), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(225), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(808), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(190), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(333), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(241), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(846), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(311), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(643), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(97), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(747), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(392), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(811), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(418), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(73), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(99), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(59), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(686), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(273), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(562), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(842), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(504), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(122), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(622), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(2), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(93), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(652), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(840), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(247), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(297), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(386), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(491), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(173), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(23), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(121), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(636), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(303), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(666), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(265), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(624), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(354), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(129), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(458), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(107), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(189), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(704), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(691), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(683), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(885), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(684), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(404), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(912), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(83), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(919), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(151), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(375), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(436), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(628), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(40), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(756), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(487), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(327), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(187), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(401), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(437), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(729), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(906), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(323), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(584), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(282), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(95), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(859), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(851), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(481), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(960), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(384), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(782), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(538), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(770), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(773), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(1), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(0), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(409), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(615), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(750), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(533), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(14), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(203), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(92), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(522), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(841), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(632), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(748), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(940), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(998), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(593), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(135), name='start shift', time=0)
# TimePoint(taxi_id=np.int64(266), name='pick up    ', time=0.03333333333333333)
# TimePoint(taxi_id=np.int64(382), name='pick up    ', time=0.05)
# TimePoint(taxi_id=np.int64(392), name='pick up    ', time=0.05)
# TimePoint(taxi_id=np.int64(95), name='pick up    ', time=0.05)
# TimePoint(taxi_id=np.int64(993), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(143), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(243), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(340), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(802), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(778), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(328), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(744), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(192), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(798), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(241), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(401), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(487), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(773), name='pick up    ', time=0.06666666666666667)
# TimePoint(taxi_id=np.int64(763), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(161), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(543), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(248), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(37), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(357), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(790), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(986), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(862), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(466), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(609), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(350), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(871), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(164), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(846), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(59), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(273), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(93), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(705), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(912), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(40), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(437), name='pick up    ', time=0.08333333333333333)
# TimePoint(taxi_id=np.int64(542), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(654), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(139), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(795), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(740), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(459), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(373), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(571), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(360), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(287), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(361), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(892), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(298), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(834), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(528), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(786), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(701), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(811), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(375), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(436), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(624), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(409), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(593), name='pick up    ', time=0.1)
# TimePoint(taxi_id=np.int64(965), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(425), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(228), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(976), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(837), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(197), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(396), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(540), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(529), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(194), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(351), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(679), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(734), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(5), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(721), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(309), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(177), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(685), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(411), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(355), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(504), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(683), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(404), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(354), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(265), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(538), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(533), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(14), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(522), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(135), name='pick up    ', time=0.11666666666666667)
# TimePoint(taxi_id=np.int64(827), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(505), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(681), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(398), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(931), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(989), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(589), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(777), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(999), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(511), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(822), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(804), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(653), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(664), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(612), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(722), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(570), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(537), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(472), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(603), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(123), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(618), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(251), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(559), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(256), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(184), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(190), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(808), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(747), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(842), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(652), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(247), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(386), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(23), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(189), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(934), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(961), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(729), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(481), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(92), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(203), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(384), name='pick up    ', time=0.13333333333333333)
# TimePoint(taxi_id=np.int64(550), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(166), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(450), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(250), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(959), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(451), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(775), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(460), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(30), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(565), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(320), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(464), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(769), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(939), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(982), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(916), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(761), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(901), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(921), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(532), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(22), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(294), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(333), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(225), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(97), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(562), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(622), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(491), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(297), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(121), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(107), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(691), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(919), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(151), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(83), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(187), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(323), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(851), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(0), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(615), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(940), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(632), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(998), name='pick up    ', time=0.15)
# TimePoint(taxi_id=np.int64(433), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(831), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(421), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(591), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(784), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(371), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(68), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(391), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(730), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(753), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(262), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(132), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(346), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(904), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(483), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(656), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(955), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(548), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(418), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(73), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(303), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(458), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(129), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(628), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(756), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(859), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(782), name='pick up    ', time=0.16666666666666666)
# TimePoint(taxi_id=np.int64(330), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(150), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(89), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(453), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(633), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(899), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(947), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(325), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(942), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(971), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(643), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(686), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(2), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(122), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(173), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(114), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(885), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(282), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(750), name='pick up    ', time=0.18333333333333332)
# TimePoint(taxi_id=np.int64(553), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(760), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(124), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(908), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(561), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(915), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(619), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(526), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(284), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(186), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(697), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(380), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(99), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(840), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(636), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(666), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(704), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(327), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(584), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(960), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(770), name='pick up    ', time=0.2)
# TimePoint(taxi_id=np.int64(926), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(665), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(710), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(889), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(678), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(909), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(906), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(841), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(748), name='pick up    ', time=0.21666666666666667)
# TimePoint(taxi_id=np.int64(214), name='pick up    ', time=0.23333333333333334)
# TimePoint(taxi_id=np.int64(100), name='pick up    ', time=0.23333333333333334)
# TimePoint(taxi_id=np.int64(975), name='pick up    ', time=0.23333333333333334)
# TimePoint(taxi_id=np.int64(311), name='pick up    ', time=0.23333333333333334)
# TimePoint(taxi_id=np.int64(684), name='pick up    ', time=0.23333333333333334)
# TimePoint(taxi_id=np.int64(1), name='pick up    ', time=0.23333333333333334)
# TimePoint(taxi_id=np.int64(866), name='pick up    ', time=0.25)
# TimePoint(taxi_id=np.int64(64), name='pick up    ', time=0.25)
# TimePoint(taxi_id=np.int64(555), name='pick up    ', time=0.2833333333333333)
# TimePoint(taxi_id=np.int64(605), name='pick up    ', time=0.2833333333333333)
# TimePoint(taxi_id=np.int64(243), name='drop off   ', time=0.6666666666666666)
# TimePoint(taxi_id=np.int64(241), name='drop off   ', time=0.6833333333333333)
# TimePoint(taxi_id=np.int64(846), name='drop off   ', time=0.6833333333333333)
# TimePoint(taxi_id=np.int64(778), name='drop off   ', time=0.7)
# TimePoint(taxi_id=np.int64(40), name='drop off   ', time=0.7000000000000001)
# TimePoint(taxi_id=np.int64(522), name='drop off   ', time=0.7000000000000001)
# TimePoint(taxi_id=np.int64(790), name='drop off   ', time=0.7166666666666667)
# TimePoint(taxi_id=np.int64(892), name='drop off   ', time=0.7166666666666667)
# TimePoint(taxi_id=np.int64(942), name='drop off   ', time=0.7166666666666667)
# TimePoint(taxi_id=np.int64(273), name='drop off   ', time=0.7166666666666667)
# TimePoint(taxi_id=np.int64(740), name='drop off   ', time=0.7333333333333333)
# TimePoint(taxi_id=np.int64(243), name='pick up    ', time=0.7333333333333333)
# TimePoint(taxi_id=np.int64(811), name='drop off   ', time=0.7333333333333333)
# TimePoint(taxi_id=np.int64(459), name='drop off   ', time=0.75)
# TimePoint(taxi_id=np.int64(532), name='drop off   ', time=0.75)
# TimePoint(taxi_id=np.int64(993), name='drop off   ', time=0.7666666666666666)
# TimePoint(taxi_id=np.int64(591), name='drop off   ', time=0.7666666666666666)
# TimePoint(taxi_id=np.int64(834), name='drop off   ', time=0.7666666666666666)
# TimePoint(taxi_id=np.int64(965), name='drop off   ', time=0.7666666666666667)
# TimePoint(taxi_id=np.int64(225), name='drop off   ', time=0.7666666666666667)
# TimePoint(taxi_id=np.int64(437), name='drop off   ', time=0.7666666666666667)
# TimePoint(taxi_id=np.int64(777), name='drop off   ', time=0.7833333333333333)
# TimePoint(taxi_id=np.int64(192), name='drop off   ', time=0.7833333333333333)
# TimePoint(taxi_id=np.int64(241), name='pick up    ', time=0.7833333333333333)
# TimePoint(taxi_id=np.int64(570), name='drop off   ', time=0.7999999999999999)
# TimePoint(taxi_id=np.int64(537), name='drop off   ', time=0.7999999999999999)
# TimePoint(taxi_id=np.int64(528), name='drop off   ', time=0.7999999999999999)
# TimePoint(taxi_id=np.int64(184), name='drop off   ', time=0.7999999999999999)
# TimePoint(taxi_id=np.int64(73), name='drop off   ', time=0.7999999999999999)
# TimePoint(taxi_id=np.int64(652), name='drop off   ', time=0.7999999999999999)
# TimePoint(taxi_id=np.int64(859), name='drop off   ', time=0.7999999999999999)
# TimePoint(taxi_id=np.int64(248), name='drop off   ', time=0.8)
# TimePoint(taxi_id=np.int64(790), name='pick up    ', time=0.8)
# TimePoint(taxi_id=np.int64(411), name='drop off   ', time=0.8)
# TimePoint(taxi_id=np.int64(491), name='drop off   ', time=0.8)
# TimePoint(taxi_id=np.int64(912), name='drop off   ', time=0.8)
# TimePoint(taxi_id=np.int64(425), name='drop off   ', time=0.8166666666666667)
# TimePoint(taxi_id=np.int64(143), name='drop off   ', time=0.8166666666666667)
# TimePoint(taxi_id=np.int64(664), name='drop off   ', time=0.8166666666666667)
# TimePoint(taxi_id=np.int64(571), name='drop off   ', time=0.8166666666666667)
# TimePoint(taxi_id=np.int64(189), name='drop off   ', time=0.8166666666666667)
# TimePoint(taxi_id=np.int64(965), name='pick up    ', time=0.8166666666666668)
# TimePoint(taxi_id=np.int64(392), name='drop off   ', time=0.8166666666666668)
# TimePoint(taxi_id=np.int64(40), name='pick up    ', time=0.8166666666666668)
# TimePoint(taxi_id=np.int64(522), name='pick up    ', time=0.8166666666666668)
# TimePoint(taxi_id=np.int64(371), name='drop off   ', time=0.8333333333333333)
# TimePoint(taxi_id=np.int64(186), name='drop off   ', time=0.8333333333333333)
# TimePoint(taxi_id=np.int64(701), name='drop off   ', time=0.8333333333333333)
# TimePoint(taxi_id=np.int64(756), name='drop off   ', time=0.8333333333333333)
# TimePoint(taxi_id=np.int64(409), name='drop off   ', time=0.8333333333333333)
# TimePoint(taxi_id=np.int64(357), name='drop off   ', time=0.8333333333333334)
# TimePoint(taxi_id=np.int64(328), name='drop off   ', time=0.8333333333333334)
# TimePoint(taxi_id=np.int64(871), name='drop off   ', time=0.8333333333333334)
# TimePoint(taxi_id=np.int64(177), name='drop off   ', time=0.8333333333333334)
# TimePoint(taxi_id=np.int64(273), name='pick up    ', time=0.8333333333333334)
# TimePoint(taxi_id=np.int64(297), name='drop off   ', time=0.8333333333333334)
# TimePoint(taxi_id=np.int64(433), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(591), name='pick up    ', time=0.85)
# TimePoint(taxi_id=np.int64(542), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(612), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(361), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(298), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(346), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(904), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(846), name='pick up    ', time=0.85)
# TimePoint(taxi_id=np.int64(303), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(265), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(187), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(481), name='drop off   ', time=0.85)
# TimePoint(taxi_id=np.int64(93), name='drop off   ', time=0.8500000000000001)
# TimePoint(taxi_id=np.int64(681), name='drop off   ', time=0.8666666666666666)
# TimePoint(taxi_id=np.int64(778), name='pick up    ', time=0.8666666666666666)
# TimePoint(taxi_id=np.int64(934), name='drop off   ', time=0.8666666666666666)
# TimePoint(taxi_id=np.int64(782), name='drop off   ', time=0.8666666666666666)
# TimePoint(taxi_id=np.int64(166), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(976), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(565), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(802), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(466), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(350), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(487), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(632), name='drop off   ', time=0.8666666666666667)
# TimePoint(taxi_id=np.int64(266), name='drop off   ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(526), name='drop off   ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(834), name='pick up    ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(942), name='pick up    ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(532), name='pick up    ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(23), name='drop off   ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(83), name='drop off   ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(584), name='drop off   ', time=0.8833333333333333)
# TimePoint(taxi_id=np.int64(529), name='drop off   ', time=0.8833333333333334)
# TimePoint(taxi_id=np.int64(540), name='drop off   ', time=0.8833333333333334)
# TimePoint(taxi_id=np.int64(685), name='drop off   ', time=0.8833333333333334)
# TimePoint(taxi_id=np.int64(355), name='drop off   ', time=0.8833333333333334)
# TimePoint(taxi_id=np.int64(354), name='drop off   ', time=0.8833333333333334)
# TimePoint(taxi_id=np.int64(811), name='pick up    ', time=0.8999999999999999)
# TimePoint(taxi_id=np.int64(770), name='drop off   ', time=0.8999999999999999)
# TimePoint(taxi_id=np.int64(763), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(143), name='pick up    ', time=0.9)
# TimePoint(taxi_id=np.int64(459), name='pick up    ', time=0.9)
# TimePoint(taxi_id=np.int64(511), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(721), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(744), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(346), name='pick up    ', time=0.9)
# TimePoint(taxi_id=np.int64(747), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(225), name='pick up    ', time=0.9)
# TimePoint(taxi_id=np.int64(97), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(107), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(691), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(851), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(533), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(14), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(615), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(593), name='drop off   ', time=0.9)
# TimePoint(taxi_id=np.int64(392), name='pick up    ', time=0.9000000000000001)
# TimePoint(taxi_id=np.int64(421), name='drop off   ', time=0.9166666666666666)
# TimePoint(taxi_id=np.int64(784), name='drop off   ', time=0.9166666666666666)
# TimePoint(taxi_id=np.int64(777), name='pick up    ', time=0.9166666666666666)
# TimePoint(taxi_id=np.int64(453), name='drop off   ', time=0.9166666666666666)
# TimePoint(taxi_id=np.int64(472), name='drop off   ', time=0.9166666666666666)
# TimePoint(taxi_id=np.int64(842), name='drop off   ', time=0.9166666666666666)
# TimePoint(taxi_id=np.int64(401), name='drop off   ', time=0.9166666666666666)
# TimePoint(taxi_id=np.int64(396), name='drop off   ', time=0.9166666666666667)
# TimePoint(taxi_id=np.int64(5), name='drop off   ', time=0.9166666666666667)
# TimePoint(taxi_id=np.int64(993), name='pick up    ', time=0.9333333333333332)
# TimePoint(taxi_id=np.int64(537), name='pick up    ', time=0.9333333333333332)
# TimePoint(taxi_id=np.int64(528), name='pick up    ', time=0.9333333333333332)
# TimePoint(taxi_id=np.int64(652), name='pick up    ', time=0.9333333333333332)
# TimePoint(taxi_id=np.int64(859), name='pick up    ', time=0.9333333333333332)
# TimePoint(taxi_id=np.int64(931), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(382), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(665), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(511), name='pick up    ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(68), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(915), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(391), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(664), name='pick up    ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(730), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(986), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(899), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(892), name='pick up    ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(123), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(294), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(411), name='pick up    ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(961), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(491), name='pick up    ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(919), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(436), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(323), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(773), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(0), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(135), name='drop off   ', time=0.9333333333333333)
# TimePoint(taxi_id=np.int64(685), name='pick up    ', time=0.9333333333333335)
# TimePoint(taxi_id=np.int64(831), name='drop off   ', time=0.95)
# TimePoint(taxi_id=np.int64(139), name='drop off   ', time=0.95)
# TimePoint(taxi_id=np.int64(999), name='drop off   ', time=0.95)
# TimePoint(taxi_id=np.int64(373), name='drop off   ', time=0.95)
# TimePoint(taxi_id=np.int64(975), name='drop off   ', time=0.95)
# TimePoint(taxi_id=np.int64(73), name='pick up    ', time=0.95)
# TimePoint(taxi_id=np.int64(189), name='pick up    ', time=0.95)
# TimePoint(taxi_id=np.int64(375), name='drop off   ', time=0.95)
# TimePoint(taxi_id=np.int64(187), name='pick up    ', time=0.95)
# TimePoint(taxi_id=np.int64(384), name='drop off   ', time=0.95)
# TimePoint(taxi_id=np.int64(959), name='drop off   ', time=0.9500000000000001)
# TimePoint(taxi_id=np.int64(451), name='drop off   ', time=0.9500000000000001)
# TimePoint(taxi_id=np.int64(197), name='drop off   ', time=0.9500000000000001)
# TimePoint(taxi_id=np.int64(150), name='drop off   ', time=0.9500000000000001)
# TimePoint(taxi_id=np.int64(862), name='drop off   ', time=0.9500000000000001)
# TimePoint(taxi_id=np.int64(609), name='drop off   ', time=0.9500000000000001)
# ...
# TimePoint(taxi_id=np.int64(369), name='end shift  ', time=23.616666666666667)
# TimePoint(taxi_id=np.int64(655), name='drop off   ', time=23.61666666666667)
# TimePoint(taxi_id=np.int64(880), name='drop off   ', time=23.61666666666667)
# TimePoint(taxi_id=np.int64(606), name='drop off   ', time=23.616666666666674)
# TimePoint(taxi_id=np.int64(964), name='pick up    ', time=23.616666666666674)
# TimePoint(taxi_id=np.int64(639), name='drop off   ', time=23.616666666666678)
# TimePoint(taxi_id=np.int64(752), name='drop off   ', time=23.616666666666678)
# TimePoint(taxi_id=np.int64(958), name='drop off   ', time=23.633333333333326)
# TimePoint(taxi_id=np.int64(447), name='pick up    ', time=23.63333333333333)
# TimePoint(taxi_id=np.int64(765), name='drop off   ', time=23.633333333333333)
# TimePoint(taxi_id=np.int64(776), name='end shift  ', time=23.633333333333333)
# TimePoint(taxi_id=np.int64(880), name='pick up    ', time=23.633333333333336)
# TimePoint(taxi_id=np.int64(737), name='drop off   ', time=23.633333333333336)
# TimePoint(taxi_id=np.int64(195), name='pick up    ', time=23.63333333333334)
# TimePoint(taxi_id=np.int64(240), name='drop off   ', time=23.63333333333334)
# TimePoint(taxi_id=np.int64(670), name='drop off   ', time=23.633333333333344)
# TimePoint(taxi_id=np.int64(903), name='drop off   ', time=23.633333333333344)
# TimePoint(taxi_id=np.int64(444), name='pick up    ', time=23.633333333333344)
# TimePoint(taxi_id=np.int64(423), name='drop off   ', time=23.633333333333344)
# TimePoint(taxi_id=np.int64(610), name='drop off   ', time=23.633333333333347)
# TimePoint(taxi_id=np.int64(163), name='pick up    ', time=23.649999999999995)
# TimePoint(taxi_id=np.int64(84), name='drop off   ', time=23.65)
# TimePoint(taxi_id=np.int64(9), name='end shift  ', time=23.65)
# TimePoint(taxi_id=np.int64(809), name='pick up    ', time=23.65)
# TimePoint(taxi_id=np.int64(809), name='drop off   ', time=23.65)
# TimePoint(taxi_id=np.int64(826), name='end shift  ', time=23.650000000000002)
# TimePoint(taxi_id=np.int64(601), name='pick up    ', time=23.650000000000002)
# TimePoint(taxi_id=np.int64(356), name='drop off   ', time=23.650000000000002)
# TimePoint(taxi_id=np.int64(917), name='drop off   ', time=23.650000000000006)
# TimePoint(taxi_id=np.int64(525), name='pick up    ', time=23.650000000000006)
# TimePoint(taxi_id=np.int64(882), name='drop off   ', time=23.650000000000006)
# TimePoint(taxi_id=np.int64(405), name='end shift  ', time=23.650000000000006)
# TimePoint(taxi_id=np.int64(515), name='end shift  ', time=23.65000000000001)
# TimePoint(taxi_id=np.int64(261), name='drop off   ', time=23.65000000000001)
# TimePoint(taxi_id=np.int64(610), name='pick up    ', time=23.650000000000013)
# TimePoint(taxi_id=np.int64(810), name='drop off   ', time=23.66666666666666)
# TimePoint(taxi_id=np.int64(292), name='end shift  ', time=23.666666666666664)
# TimePoint(taxi_id=np.int64(754), name='drop off   ', time=23.666666666666664)
# TimePoint(taxi_id=np.int64(253), name='end shift  ', time=23.666666666666668)
# TimePoint(taxi_id=np.int64(172), name='drop off   ', time=23.666666666666668)
# TimePoint(taxi_id=np.int64(598), name='drop off   ', time=23.66666666666667)
# TimePoint(taxi_id=np.int64(201), name='drop off   ', time=23.66666666666667)
# TimePoint(taxi_id=np.int64(625), name='drop off   ', time=23.666666666666675)
# TimePoint(taxi_id=np.int64(31), name='pick up    ', time=23.666666666666675)
# TimePoint(taxi_id=np.int64(238), name='pick up    ', time=23.66666666666668)
# TimePoint(taxi_id=np.int64(920), name='pick up    ', time=23.68333333333333)
# TimePoint(taxi_id=np.int64(368), name='drop off   ', time=23.683333333333334)
# TimePoint(taxi_id=np.int64(699), name='end shift  ', time=23.683333333333334)
# TimePoint(taxi_id=np.int64(728), name='drop off   ', time=23.683333333333337)
# TimePoint(taxi_id=np.int64(655), name='pick up    ', time=23.683333333333337)
# TimePoint(taxi_id=np.int64(692), name='pick up    ', time=23.68333333333334)
# TimePoint(taxi_id=np.int64(423), name='pick up    ', time=23.683333333333344)
# TimePoint(taxi_id=np.int64(670), name='pick up    ', time=23.683333333333344)
# TimePoint(taxi_id=np.int64(564), name='drop off   ', time=23.683333333333344)
# TimePoint(taxi_id=np.int64(422), name='drop off   ', time=23.699999999999992)
# TimePoint(taxi_id=np.int64(797), name='drop off   ', time=23.7)
# TimePoint(taxi_id=np.int64(356), name='pick up    ', time=23.700000000000003)
# TimePoint(taxi_id=np.int64(833), name='drop off   ', time=23.700000000000006)
# TimePoint(taxi_id=np.int64(547), name='drop off   ', time=23.700000000000006)
# TimePoint(taxi_id=np.int64(864), name='drop off   ', time=23.700000000000006)
# TimePoint(taxi_id=np.int64(896), name='drop off   ', time=23.700000000000006)
# TimePoint(taxi_id=np.int64(639), name='pick up    ', time=23.70000000000001)
# TimePoint(taxi_id=np.int64(534), name='pick up    ', time=23.70000000000001)
# TimePoint(taxi_id=np.int64(810), name='pick up    ', time=23.71666666666666)
# TimePoint(taxi_id=np.int64(10), name='pick up    ', time=23.71666666666666)
# TimePoint(taxi_id=np.int64(958), name='end shift  ', time=23.71666666666666)
# TimePoint(taxi_id=np.int64(952), name='drop off   ', time=23.716666666666665)
# TimePoint(taxi_id=np.int64(817), name='drop off   ', time=23.71666666666667)
# TimePoint(taxi_id=np.int64(310), name='drop off   ', time=23.71666666666667)
# TimePoint(taxi_id=np.int64(113), name='drop off   ', time=23.71666666666667)
# TimePoint(taxi_id=np.int64(172), name='pick up    ', time=23.71666666666667)
# TimePoint(taxi_id=np.int64(429), name='drop off   ', time=23.71666666666667)
# TimePoint(taxi_id=np.int64(882), name='pick up    ', time=23.716666666666672)
# TimePoint(taxi_id=np.int64(917), name='pick up    ', time=23.716666666666672)
# TimePoint(taxi_id=np.int64(556), name='drop off   ', time=23.71666666666668)
# TimePoint(taxi_id=np.int64(229), name='drop off   ', time=23.733333333333327)
# TimePoint(taxi_id=np.int64(783), name='drop off   ', time=23.73333333333333)
# TimePoint(taxi_id=np.int64(830), name='drop off   ', time=23.733333333333334)
# TimePoint(taxi_id=np.int64(310), name='pick up    ', time=23.733333333333334)
# TimePoint(taxi_id=np.int64(765), name='pick up    ', time=23.733333333333334)
# TimePoint(taxi_id=np.int64(368), name='pick up    ', time=23.733333333333334)
# TimePoint(taxi_id=np.int64(888), name='drop off   ', time=23.733333333333338)
# TimePoint(taxi_id=np.int64(16), name='drop off   ', time=23.733333333333338)
# TimePoint(taxi_id=np.int64(201), name='pick up    ', time=23.733333333333338)
# TimePoint(taxi_id=np.int64(737), name='end shift  ', time=23.733333333333338)
# TimePoint(taxi_id=np.int64(240), name='pick up    ', time=23.73333333333334)
# TimePoint(taxi_id=np.int64(752), name='end shift  ', time=23.733333333333345)
# TimePoint(taxi_id=np.int64(608), name='drop off   ', time=23.733333333333345)
# TimePoint(taxi_id=np.int64(496), name='drop off   ', time=23.749999999999986)
# TimePoint(taxi_id=np.int64(514), name='drop off   ', time=23.749999999999993)
# TimePoint(taxi_id=np.int64(754), name='pick up    ', time=23.749999999999996)
# TimePoint(taxi_id=np.int64(554), name='pick up    ', time=23.75)
# TimePoint(taxi_id=np.int64(54), name='pick up    ', time=23.75)
# TimePoint(taxi_id=np.int64(554), name='drop off   ', time=23.75)
# TimePoint(taxi_id=np.int64(131), name='drop off   ', time=23.750000000000004)
# TimePoint(taxi_id=np.int64(625), name='pick up    ', time=23.750000000000007)
# TimePoint(taxi_id=np.int64(977), name='end shift  ', time=23.750000000000007)
# TimePoint(taxi_id=np.int64(261), name='pick up    ', time=23.75000000000001)
# TimePoint(taxi_id=np.int64(556), name='pick up    ', time=23.750000000000014)
# TimePoint(taxi_id=np.int64(800), name='drop off   ', time=23.76666666666666)
# TimePoint(taxi_id=np.int64(219), name='drop off   ', time=23.766666666666666)
# TimePoint(taxi_id=np.int64(475), name='drop off   ', time=23.766666666666666)
# TimePoint(taxi_id=np.int64(577), name='drop off   ', time=23.766666666666666)
# TimePoint(taxi_id=np.int64(830), name='pick up    ', time=23.76666666666667)
# TimePoint(taxi_id=np.int64(833), name='pick up    ', time=23.766666666666673)
# TimePoint(taxi_id=np.int64(260), name='drop off   ', time=23.766666666666673)
# TimePoint(taxi_id=np.int64(764), name='drop off   ', time=23.766666666666676)
# TimePoint(taxi_id=np.int64(564), name='pick up    ', time=23.766666666666676)
# TimePoint(taxi_id=np.int64(84), name='pick up    ', time=23.78333333333333)
# TimePoint(taxi_id=np.int64(877), name='drop off   ', time=23.78333333333333)
# TimePoint(taxi_id=np.int64(606), name='end shift  ', time=23.78333333333334)
# TimePoint(taxi_id=np.int64(728), name='pick up    ', time=23.78333333333334)
# TimePoint(taxi_id=np.int64(903), name='end shift  ', time=23.783333333333342)
# TimePoint(taxi_id=np.int64(289), name='end shift  ', time=23.783333333333346)
# TimePoint(taxi_id=np.int64(496), name='pick up    ', time=23.799999999999986)
# TimePoint(taxi_id=np.int64(229), name='pick up    ', time=23.799999999999994)
# TimePoint(taxi_id=np.int64(675), name='drop off   ', time=23.8)
# TimePoint(taxi_id=np.int64(797), name='pick up    ', time=23.8)
# TimePoint(taxi_id=np.int64(429), name='pick up    ', time=23.8)
# TimePoint(taxi_id=np.int64(604), name='drop off   ', time=23.800000000000004)
# TimePoint(taxi_id=np.int64(764), name='pick up    ', time=23.80000000000001)
# TimePoint(taxi_id=np.int64(626), name='drop off   ', time=23.80000000000001)
# TimePoint(taxi_id=np.int64(457), name='drop off   ', time=23.816666666666663)
# TimePoint(taxi_id=np.int64(260), name='pick up    ', time=23.816666666666674)
# TimePoint(taxi_id=np.int64(994), name='drop off   ', time=23.83333333333332)
# TimePoint(taxi_id=np.int64(800), name='pick up    ', time=23.833333333333325)
# TimePoint(taxi_id=np.int64(422), name='end shift  ', time=23.833333333333325)
# TimePoint(taxi_id=np.int64(475), name='pick up    ', time=23.833333333333332)
# TimePoint(taxi_id=np.int64(428), name='drop off   ', time=23.833333333333336)
# TimePoint(taxi_id=np.int64(817), name='pick up    ', time=23.833333333333336)
# TimePoint(taxi_id=np.int64(709), name='drop off   ', time=23.83333333333334)
# TimePoint(taxi_id=np.int64(864), name='pick up    ', time=23.83333333333334)
# TimePoint(taxi_id=np.int64(199), name='drop off   ', time=23.83333333333335)
# TimePoint(taxi_id=np.int64(523), name='drop off   ', time=23.85)
# TimePoint(taxi_id=np.int64(803), name='drop off   ', time=23.850000000000005)
# TimePoint(taxi_id=np.int64(16), name='pick up    ', time=23.850000000000005)
# TimePoint(taxi_id=np.int64(598), name='end shift  ', time=23.850000000000005)
# TimePoint(taxi_id=np.int64(126), name='drop off   ', time=23.85000000000001)
# TimePoint(taxi_id=np.int64(463), name='drop off   ', time=23.850000000000012)
# TimePoint(taxi_id=np.int64(838), name='drop off   ', time=23.850000000000016)
# TimePoint(taxi_id=np.int64(877), name='pick up    ', time=23.866666666666664)
# TimePoint(taxi_id=np.int64(557), name='drop off   ', time=23.866666666666667)
# TimePoint(taxi_id=np.int64(577), name='pick up    ', time=23.866666666666667)
# TimePoint(taxi_id=np.int64(69), name='drop off   ', time=23.866666666666667)
# TimePoint(taxi_id=np.int64(219), name='pick up    ', time=23.866666666666667)
# TimePoint(taxi_id=np.int64(222), name='drop off   ', time=23.86666666666667)
# TimePoint(taxi_id=np.int64(131), name='pick up    ', time=23.86666666666667)
# TimePoint(taxi_id=np.int64(608), name='end shift  ', time=23.86666666666668)
# TimePoint(taxi_id=np.int64(440), name='drop off   ', time=23.88333333333333)
# TimePoint(taxi_id=np.int64(578), name='drop off   ', time=23.883333333333333)
# TimePoint(taxi_id=np.int64(888), name='end shift  ', time=23.883333333333336)
# TimePoint(taxi_id=np.int64(428), name='pick up    ', time=23.883333333333336)
# TimePoint(taxi_id=np.int64(113), name='pick up    ', time=23.883333333333336)
# TimePoint(taxi_id=np.int64(32), name='drop off   ', time=23.88333333333334)
# TimePoint(taxi_id=np.int64(271), name='drop off   ', time=23.88333333333334)
# TimePoint(taxi_id=np.int64(547), name='end shift  ', time=23.88333333333334)
# TimePoint(taxi_id=np.int64(474), name='drop off   ', time=23.89999999999999)
# TimePoint(taxi_id=np.int64(514), name='pick up    ', time=23.89999999999999)
# TimePoint(taxi_id=np.int64(925), name='drop off   ', time=23.899999999999995)
# TimePoint(taxi_id=np.int64(733), name='end shift  ', time=23.899999999999995)
# TimePoint(taxi_id=np.int64(57), name='drop off   ', time=23.9)
# TimePoint(taxi_id=np.int64(557), name='pick up    ', time=23.900000000000002)
# TimePoint(taxi_id=np.int64(675), name='pick up    ', time=23.900000000000002)
# TimePoint(taxi_id=np.int64(709), name='pick up    ', time=23.900000000000006)
# TimePoint(taxi_id=np.int64(981), name='drop off   ', time=23.900000000000006)
# TimePoint(taxi_id=np.int64(39), name='drop off   ', time=23.900000000000006)
# TimePoint(taxi_id=np.int64(488), name='drop off   ', time=23.90000000000001)
# TimePoint(taxi_id=np.int64(626), name='end shift  ', time=23.90000000000001)
# TimePoint(taxi_id=np.int64(896), name='end shift  ', time=23.90000000000001)
# TimePoint(taxi_id=np.int64(952), name='end shift  ', time=23.916666666666664)
# TimePoint(taxi_id=np.int64(783), name='end shift  ', time=23.916666666666664)
# TimePoint(taxi_id=np.int64(75), name='drop off   ', time=23.916666666666664)
# TimePoint(taxi_id=np.int64(455), name='drop off   ', time=23.916666666666668)
# TimePoint(taxi_id=np.int64(233), name='drop off   ', time=23.916666666666668)
# TimePoint(taxi_id=np.int64(523), name='pick up    ', time=23.916666666666668)
# TimePoint(taxi_id=np.int64(852), name='drop off   ', time=23.91666666666667)
# TimePoint(taxi_id=np.int64(981), name='pick up    ', time=23.91666666666667)
# TimePoint(taxi_id=np.int64(222), name='pick up    ', time=23.91666666666667)
# TimePoint(taxi_id=np.int64(32), name='pick up    ', time=23.916666666666675)
# TimePoint(taxi_id=np.int64(994), name='end shift  ', time=23.933333333333323)
# TimePoint(taxi_id=np.int64(69), name='pick up    ', time=23.933333333333334)
# TimePoint(taxi_id=np.int64(604), name='end shift  ', time=23.933333333333337)
# TimePoint(taxi_id=np.int64(863), name='drop off   ', time=23.933333333333337)
# TimePoint(taxi_id=np.int64(305), name='drop off   ', time=23.933333333333337)
# TimePoint(taxi_id=np.int64(31), name='drop off   ', time=23.93333333333334)
# TimePoint(taxi_id=np.int64(199), name='end shift  ', time=23.93333333333335)
# TimePoint(taxi_id=np.int64(457), name='end shift  ', time=23.95)
# TimePoint(taxi_id=np.int64(578), name='end shift  ', time=23.950000000000003)
# TimePoint(taxi_id=np.int64(803), name='pick up    ', time=23.950000000000006)
# TimePoint(taxi_id=np.int64(430), name='drop off   ', time=23.95000000000001)
# TimePoint(taxi_id=np.int64(474), name='end shift  ', time=23.966666666666658)
# TimePoint(taxi_id=np.int64(925), name='pick up    ', time=23.96666666666666)
# TimePoint(taxi_id=np.int64(613), name='drop off   ', time=23.966666666666665)
# TimePoint(taxi_id=np.int64(895), name='drop off   ', time=23.96666666666667)
# TimePoint(taxi_id=np.int64(444), name='drop off   ', time=23.966666666666676)
# TimePoint(taxi_id=np.int64(126), name='pick up    ', time=23.966666666666676)
# TimePoint(taxi_id=np.int64(463), name='end shift  ', time=23.96666666666668)
# TimePoint(taxi_id=np.int64(63), name='drop off   ', time=23.983333333333327)
# TimePoint(taxi_id=np.int64(796), name='drop off   ', time=23.983333333333327)
# TimePoint(taxi_id=np.int64(552), name='drop off   ', time=23.98333333333333)
# TimePoint(taxi_id=np.int64(57), name='end shift  ', time=23.983333333333334)
# TimePoint(taxi_id=np.int64(863), name='pick up    ', time=23.983333333333338)
# TimePoint(taxi_id=np.int64(305), name='pick up    ', time=23.983333333333338)
# TimePoint(taxi_id=np.int64(534), name='drop off   ', time=23.983333333333345)
# TimePoint(taxi_id=np.int64(838), name='end shift  ', time=23.98333333333335)
# TimePoint(taxi_id=np.int64(613), name='end shift  ', time=23.999999999999996)
# TimePoint(taxi_id=np.int64(447), name='drop off   ', time=23.999999999999996)
# TimePoint(taxi_id=np.int64(973), name='drop off   ', time=24.0)
